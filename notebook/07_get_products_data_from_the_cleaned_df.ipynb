# %%
import pandas as pd

df = pd.read_csv(r'products.csv')

# %%
df
# Out:
#    product_id                                               name  \
# 0           1  Herforte Lotion Spray (to fill in gaps and tre...
# 1           2  Hairforte Shampoo (for treating hair loss and ...
# 2           3                           Valdo moisturizing cream
# 3           4  Spleet Cream Scrub (Steam Alternative + Acne T...
# 4           5  Spleet Lightening Cream (for treating pigmenta...
# 5           6  Spleet Eye Contour Cream (for treating dark ci...
# 6           7                                 Spleet Facial wash
# 7          12                     Aceto-V Feminine Intimate wash
#
#                                          description  price  \
# 0  Hair forte is a mixture of natural extracts an...  200.0
# 1  Hair Forte shampoo is an effective combination...  150.0
# 2  Valdo Moisturizing Cream -The best moisturizin...   80.0
# 3  Spleet is a gentle exfoliating cream with a un...  100.0
# 4  Spleet whitening cream offers the strongest un...  100.0
# ...

# %%
# ... existing code ...

import pandas as pd

def get_unique_values(df, column):
    # Split comma-separated values, strip whitespace, and flatten the list
    return set(
        item.strip()
        for sublist in df[column].dropna().str.split(',')
        for item in sublist
    )

unique_categories = get_unique_values(df, 'category')
unique_concerns = get_unique_values(df, 'concerns')
unique_ingredients = get_unique_values(df, 'ingredients')

print("Unique Categories:", unique_categories)
print("Unique Concerns:", unique_concerns)
print("Unique Ingredients:", unique_ingredients)

# ... existing code ...
# Out:
# Unique Categories: {'Eye cream', 'Hair spray& lotion', 'Moisturizer', 'Hair Care', 'Whitening cream', 'Shampoos', 'Soft peel and Exfoliant', 'Personal Care', 'Cleansers', 'Skin Care'}
# Unique Concerns: {'Sensitive areas& Bikini area brightening', 'Hair loss', 'Strawberry skin treatment', 'Dandruff', 'Eczema & Dry skin', 'Hyperpigmentation& dark spots', 'Dark circles “blue- brown- black” & puffiness', 'Acne& acne spots', 'Dull& pale skin'}
# ...
